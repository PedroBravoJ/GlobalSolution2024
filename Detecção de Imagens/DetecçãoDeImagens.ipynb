# %% [markdown]
# # **Detecção de Imagens OceanCare**
#
# # **[VÍDEO](https://www.youtube.com/watch?v=Vk8SHDVclRU)**
#
#
# ## Objetivo
#
# - O algoritmo foi aplicado com o intuito de identificar espécies nativas, invasoras e lixo no mar, em ecossistemas específicos, para prevenir desequilibrios na fauna e flora local, além de, através da detecção de seres invasores, servir de alerta para surgimento de investigações mais profundas acerca da causa da aparição dessas espécies exóticas no ambiente monitorado. Também, com a identificação de tipos de lixo específicos, é possível analisar regiões carentes de uma limpeza e coleta dos resíduos vazados ao mar. Portanto, o ponto de chegada deste segmento do projeto consiste no constante monitoramento e vigilância de regiões marinhas específicas, promovendo a preservação do oceano.
#
# ## Base de pesquisa
#
# - Atualmente, foram escolhidos os Recifes de Coral para realizar o monitoramento. Os recifes são ecossistemas de extrema biodiversidade e produtividade, suportando, em diversas regiões, atividades de turismo e pesca.
#
# - Para o teste da implementação, foram escolhidas 13 classes a serem identificadas pelo modelo, sendo elas 5 espécies nativas, 5 espécies invasoras e 3 tipos de lixo:
#
# ### - Espécies Nativas
# 1.   Tartaruga Marinha (Chelonioidea)
# 2.   Peixe Palhaço (Amphiprioninae)
# 3.   Peixe Papagaio (Scaridae)
# 4.   Peixe Anjo (Pomacanthidae)
# 5.   Estrela-do-Mar (Asteroidea)
#
# ### - Espécies Invasoras
# 1.   Peixe Leão (Pterois volitans)
# 2.   Coral-Sol (Tubastraea coccinea/Tubastraea tagusensis)
# 3.   Mexilhão Zebra (Dreissena polymorpha)
# 4.   Molusco Asiático (Potamocorbula amurensis)
# 5.   Alga Assassina (Caulerpa taxifolia)
#
# ### - Lixo
# 1.   Bitucas de Cigarro
# 2.   Garrafas Pet
# 3.   Sacolas Plásticas
#
# ## Tecnologias utilizadas
#
# - Para treinamento do modelo foi utilizado a ferramenta de detecção de objetos do  [Roboflow](https://roboflow.com/). Foram utilizadas 140 imagens para o treinamento (de 10 a 12 imagens para cada classe, aproximadamente).
#
# ![metricasroboflow.PNG](data:image/png;base64,...)
# - Para visualização das imagens na apresentação abaixo, foi utilizada a função [Display](https://ipython.readthedocs.io/en/stable/api/generated/IPython.display.html) da biblioteca IPython.
#
# ## Fontes utilizadas
#
# - [WikiPedia: Recife de coral](https://pt.wikipedia.org/wiki/Recife_de_coral)
#
# - [Reef Resilience Network: Ecologia de recife de coral](https://reefresilience.org/pt/coral-reef-ecology/)
#
# - [Reef Resilience Network: Ameaças Locais](https://reefresilience.org/pt/stressors/local-stressors/)
#
# - [Ministério do Meio Ambiente e Mudança do Clima](https://www.gov.br/mma/pt-br/assuntos/biodiversidade-e-ecossistemas/fauna-e-flora/especies-exoticas-invasoras)

# %% [markdown]
# # **Configuração do RoboFlow**

# %% [markdown]
# ## **Instalação da biblioteca do RoboFlow**

# %%
# !pip install roboflow

# %% [markdown]
# ## **Importação do projeto e modelo treinado**

# %%
# Bibloteca display para visualização de imagem e roboflow para importação do modelo

from IPython.display import Image, display
from roboflow import Roboflow

# Informações do projeto para importação do modelo
rf = Roboflow(api_key="oE2Q8k0oqurzBkAB1ChH")
project = rf.workspace("fiap-oyi3k").project("oceano-kxk4m")
version = project.version(1)
model = project.version(1).model
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# Função que identifica a espécie identificada e sua categoria, retornando uma mensagem

def categoria(modelo):
  if 'nativo' in modelo['predictions'][0]['class']:
    print(f"A espécie é nativa!! (classe: {modelo['predictions'][0]['class']})")
  elif 'invasor' in modelo['predictions'][0]['class']:
    print(f"A espécie é invasora, perigo de desequilíbrio da fauna do ecossistema!! (classe: {modelo['predictions'][0]['class']})")
  elif 'lixo' in modelo['predictions'][0]['class']:
    print(f"Lixo encontrado no mar!! (classe: {modelo['predictions'][0]['class']})")
  else:
    print("Nenhum objeto ou espécie identificado...")

# %% [markdown]
# # **Teste Do Modelo**

# %% [markdown]
# ## **Espécies Nativas**

# %% [markdown]
# ### **Tartaruga Marinha (Chelonioidea)**

# %%
# Imagem para teste do modelo:
modelo = model.predict("/content/tartaruga.jpeg", confidence=40, overlap=30).json()
print(modelo)
# Out:
# {'predictions': [{'x': 109.5, 'y': 74.0, 'width': 191.0, 'height': 126.0, 'confidence': 0.584915816783905, 'class': 'nativo-tartaruga-marinha', 'class_id': 12, 'detection_id': 'c2dd100e-e2d5-4dd5-9551-ef88918181ac', 'image_path': '/content/tartaruga.jpeg', 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': '275', 'height': '183'}}

# %%
# Imagem para teste do modelo:
model.predict("/content/tartaruga.jpeg", confidence=40, overlap=30).save("/content/tartaruga-processed.jpg")

# %%
categoria(modelo)
# Out:
# A espécie é nativa!! (classe: nativo-tartaruga-marinha)

# %%
display(Image(filename="/content/tartaruga-processed.jpg"))

# %% [markdown]
# ### **Peixe Palhaço (Amphiprioninae)**

# %%
# Imagem para teste do modelo:
modelo = model.predict("/content/palhaço.jpg", confidence=40, overlap=30).json()
print(modelo)
# Out:
# {'predictions': [{'x': 316, 'y': 376, 'width': 198, 'height': 145, 'confidence': 0.9472657442092896, 'class': 'nativo-peixe-palhaco', 'class_id': 10, 'detection_id': 'e097ee27-e74a-4e98-840b-fb1f4f3524b4', 'image_path': '/content/palhaço.jpg', 'prediction_type': 'ObjectDetectionModel'}, {'x': 318, 'y': 135, 'width': 166, 'height': 61, 'confidence': 0.9315124154090881, 'class': 'nativo-peixe-palhaco', 'class_id': 10, 'detection_id': '55ace25b-3ab7-47d0-aea2-7542c8e0aa60', 'image_path': '/content/palhaço.jpg', 'prediction_type': 'ObjectDetectionModel'}, {'x': 85, 'y': 70, 'width': 100, 'height': 47, 'confidence': 0.928399384021759, 'class': 'nativo-peixe-palhaco', 'class_id': 10, 'detection_id': '2f383c1c-977d-4293-b3b1-301f4ea91aa2', 'image_path': '/content/palhaço.jpg', 'prediction_type': 'ObjectDetectionModel'}, {'x': 113, 'y': 318, 'width': 142, 'height': 139, 'confidence': 0.8901028633117676, 'class': 'nativo-peixe-palhaco', 'class_id': 10, 'detection_id': 'd2a6ae71-c4ad-4061-9a9f
# ...

# %%
# Imagem para teste do modelo:
model.predict("/content/palhaço.jpg", confidence=40, overlap=30).save("/content/palhaço-processed.jpg")

# %%
categoria(modelo)
# Out:
# A espécie é nativa!! (classe: nativo-peixe-palhaco)

# %%
display(Image(filename="/content/palhaço-processed.jpg"))

# %% [markdown]
# ### **Peixe Papagaio (Scaridae)**

# %%
# Imagem para teste do modelo:
modelo = model.predict("/content/papagaio.jpg", confidence=40, overlap=30).json()
print(modelo)
# Out:
# {'predictions': [{'x': 792, 'y': 304, 'width': 706, 'height': 341, 'confidence': 0.9075394868850708, 'class': 'nativo-peixe-papagaio', 'class_id': 11, 'detection_id': '995ee860-5bfd-4249-8f46-cbce2752545b', 'image_path': '/content/papagaio.jpg', 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': '1200', 'height': '600'}}

# %%
# Imagem para teste do modelo:
model.predict("/content/papagaio.jpg", confidence=40, overlap=30).save("/content/papagaio-processed.jpg")

# %%
categoria(modelo)
# Out:
# A espécie é nativa!! (classe: nativo-peixe-papagaio)

# %%
display(Image(filename="/content/papagaio-processed.jpg"))

# %% [markdown]
# ### **Peixe Anjo (Pomacanthidae)**

# %%
# Imagem para teste do modelo:
modelo = model.predict("/content/anjo.jpeg", confidence=40, overlap=30).json()
print(modelo)
# Out:
# {'predictions': [{'x': 416, 'y': 236, 'width': 658, 'height': 378, 'confidence': 0.8815791010856628, 'class': 'nativo-peixe-anjo', 'class_id': 9, 'detection_id': 'eebebf5c-6b01-4c9f-9597-89b8bacb66c4', 'image_path': '/content/anjo.jpeg', 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': '860', 'height': '482'}}

# %%
# Imagem para teste do modelo:
model.predict("/content/anjo.jpeg", confidence=40, overlap=30).save("/content/anjo-processed.jpg")

# %%
categoria(modelo)
# Out:
# A espécie é nativa!! (classe: nativo-peixe-anjo)

# %%
display(Image(filename="/content/anjo-processed.jpg"))

# %% [markdown]
# ### **Estrela-do-Mar (Asteroidea)**

# %%
# Imagem para teste do modelo:
modelo = model.predict("/content/estrela.jpg", confidence=40, overlap=30).json()
print(modelo)
# Out:
# {'predictions': [{'x': 410, 'y': 247, 'width': 533, 'height': 455, 'confidence': 0.7662811279296875, 'class': 'nativo-estrela-do-mar', 'class_id': 8, 'detection_id': 'df803a08-2de2-4b4c-b86f-2914a4d1f26e', 'image_path': '/content/estrela.jpg', 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': '800', 'height': '480'}}

# %%
# Imagem para teste do modelo:
model.predict("/content/estrela.jpg", confidence=40, overlap=30).save("/content/estrela-processed.jpg")

# %%
categoria(modelo)
# Out:
# A espécie é nativa!! (classe: nativo-estrela-do-mar)

# %%
display(Image(filename="/content/estrela-processed.jpg"))

# %% [markdown]
# ## **Espécies Invasoras**

# %% [markdown]
# ### **Peixe Leão (Pterois volitans)**

# %%
# Imagem para teste do modelo:
modelo = model.predict("/content/leao.jpg", confidence=40, overlap=30).json()
print(modelo)
# Out:
# {'predictions': [{'x': 812, 'y': 683, 'width': 1291, 'height': 1253, 'confidence': 0.9516716599464417, 'class': 'invasor-peixe-leao', 'class_id': 4, 'detection_id': 'c797542c-43d8-4d48-9b16-625db6100988', 'image_path': '/content/leao.jpg', 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': '1500', 'height': '1500'}}

# %%
# Imagem para teste do modelo:
model.predict("/content/leao.jpg", confidence=40, overlap=30).save("/content/leao-processed.jpg")

# %%
categoria(modelo)
# Out:
# A espécie é invasora, perigo de desequilíbrio da fauna do ecossistema!! (classe: invasor-peixe-leao)

# %%
display(Image(filename="/content/leao-processed.jpg"))

# %% [markdown]
# ### **Coral-Sol (Tubastraea coccinea/Tubastraea tagusensis)**

# %%
# Imagem para teste do modelo:
modelo = model.predict("/content/coralsol.jpg", confidence=40, overlap=30).json()
print(modelo)
# Out:
# {'predictions': [{'x': 659, 'y': 291, 'width': 111, 'height': 100, 'confidence': 0.9633615016937256, 'class': 'invasor-coral-sol', 'class_id': 1, 'detection_id': 'ed754704-d2ba-41fc-bb19-78f6d0161b40', 'image_path': '/content/coralsol.jpg', 'prediction_type': 'ObjectDetectionModel'}, {'x': 484, 'y': 528, 'width': 131, 'height': 115, 'confidence': 0.9622536897659302, 'class': 'invasor-coral-sol', 'class_id': 1, 'detection_id': '1d233fb8-735c-4a62-a2ff-0bfa7c568a92', 'image_path': '/content/coralsol.jpg', 'prediction_type': 'ObjectDetectionModel'}, {'x': 367, 'y': 468, 'width': 102, 'height': 92, 'confidence': 0.9573372602462769, 'class': 'invasor-coral-sol', 'class_id': 1, 'detection_id': '44e55674-6462-4928-a4bf-a1156027b0b2', 'image_path': '/content/coralsol.jpg', 'prediction_type': 'ObjectDetectionModel'}, {'x': 656, 'y': 417, 'width': 145, 'height': 115, 'confidence': 0.9541028141975403, 'class': 'invasor-coral-sol', 'class_id': 1, 'detection_id': 'ffba69c5-e329-44e2-871d-5a81be62
# ...

# %%
# Imagem para teste do modelo:
model.predict("/content/coralsol.jpg", confidence=40, overlap=30).save("/content/coralsol-processed.jpg")

# %%
categoria(modelo)
# Out:
# A espécie é invasora, perigo de desequilíbrio da fauna do ecossistema!! (classe: invasor-coral-sol)

# %%
display(Image(filename="/content/coralsol-processed.jpg"))

# %% [markdown]
# ### **Mexilhão Zebra (Dreissena polymorpha)**

# %%
# Imagem para teste do modelo:
modelo = model.predict("/content/mexilhaozebra.jpeg", confidence=40, overlap=30).json()
print(modelo)
# Out:
# {'predictions': [{'x': 52.0, 'y': 87.5, 'width': 86.0, 'height': 69.0, 'confidence': 0.9578399658203125, 'class': 'invasor-mexilhao-zebra', 'class_id': 2, 'detection_id': 'abd4dd4d-e8ba-4f56-8c3b-531ea021bc4a', 'image_path': '/content/mexilhaozebra.jpeg', 'prediction_type': 'ObjectDetectionModel'}, {'x': 159.5, 'y': 104.5, 'width': 79.0, 'height': 83.0, 'confidence': 0.9332873821258545, 'class': 'invasor-mexilhao-zebra', 'class_id': 2, 'detection_id': 'a66db8c6-1141-4065-b5f8-4734a46bb1a4', 'image_path': '/content/mexilhaozebra.jpeg', 'prediction_type': 'ObjectDetectionModel'}, {'x': 174.0, 'y': 196.0, 'width': 54.0, 'height': 88.0, 'confidence': 0.9103601574897766, 'class': 'invasor-mexilhao-zebra', 'class_id': 2, 'detection_id': 'cd88efcc-5902-4bc5-b6f4-b8fb9e045233', 'image_path': '/content/mexilhaozebra.jpeg', 'prediction_type': 'ObjectDetectionModel'}, {'x': 81.0, 'y': 184.5, 'width': 66.0, 'height': 91.0, 'confidence': 0.8729963898658752, 'class': 'invasor-mexilhao-zebra', 'cla
# ...

# %%
# Imagem para teste do modelo:
model.predict("/content/mexilhaozebra.jpeg", confidence=40, overlap=30).save("/content/mexilhaozebra-processed.jpg")

# %%
categoria(modelo)
# Out:
# A espécie é invasora, perigo de desequilíbrio da fauna do ecossistema!! (classe: invasor-mexilhao-zebra)

# %%
display(Image(filename="/content/mexilhaozebra-processed.jpg"))

# %% [markdown]
# ### **Molusco Asiático (Potamocorbula amurensis)**

# %%
# Imagem para teste do modelo:
modelo = model.predict("/content/molusco.jpeg", confidence=40, overlap=30).json()
print(modelo)
# Out:
# {'predictions': [{'x': 71.5, 'y': 95.5, 'width': 83.0, 'height': 97.0, 'confidence': 0.8604029417037964, 'class': 'invasor-molusco-asiatico', 'class_id': 3, 'detection_id': '5ddbb9e5-03ee-405d-8059-d0520620c883', 'image_path': '/content/molusco.jpeg', 'prediction_type': 'ObjectDetectionModel'}, {'x': 192.5, 'y': 101.0, 'width': 87.0, 'height': 106.0, 'confidence': 0.6920915246009827, 'class': 'invasor-molusco-asiatico', 'class_id': 3, 'detection_id': '9aacdc83-4d30-4fc3-b1dc-cbc82ed21bcb', 'image_path': '/content/molusco.jpeg', 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': '259', 'height': '194'}}

# %%
# Imagem para teste do modelo:
model.predict("/content/molusco.jpeg", confidence=40, overlap=30).save("/content/molusco-processed.jpg")

# %%
categoria(modelo)
# Out:
# A espécie é invasora, perigo de desequilíbrio da fauna do ecossistema!! (classe: invasor-molusco-asiatico)

# %%
display(Image(filename="/content/molusco-processed.jpg"))

# %% [markdown]
# ### **Alga Assassina (Caulerpa taxifolia)**

# %%
# Imagem para teste do modelo:
modelo = model.predict("/content/alga.jpg", confidence=40, overlap=30).json()
print(modelo)
# Out:
# {'predictions': [{'x': 372.5, 'y': 282.5, 'width': 87.0, 'height': 251.0, 'confidence': 0.9464661478996277, 'class': 'invasor-alga-assassina', 'class_id': 0, 'detection_id': '7dfc64cf-9889-4b96-9eb6-bcc603aaf6c0', 'image_path': '/content/alga.jpg', 'prediction_type': 'ObjectDetectionModel'}, {'x': 135.5, 'y': 244.5, 'width': 107.0, 'height': 281.0, 'confidence': 0.916172444820404, 'class': 'invasor-alga-assassina', 'class_id': 0, 'detection_id': '148cf8ee-f9a3-46c4-8262-51a366402305', 'image_path': '/content/alga.jpg', 'prediction_type': 'ObjectDetectionModel'}, {'x': 77.5, 'y': 106.5, 'width': 65.0, 'height': 163.0, 'confidence': 0.8899072408676147, 'class': 'invasor-alga-assassina', 'class_id': 0, 'detection_id': '95ed5d98-1c83-4fa5-b6e0-d1c5ee62a5df', 'image_path': '/content/alga.jpg', 'prediction_type': 'ObjectDetectionModel'}, {'x': 53.0, 'y': 257.5, 'width': 78.0, 'height': 167.0, 'confidence': 0.8611486554145813, 'class': 'invasor-alga-assassina', 'class_id': 0, 'detection_id'
# ...

# %%
# Imagem para teste do modelo:
model.predict("/content/alga.jpg", confidence=40, overlap=30).save("/content/alga-processed.jpg")

# %%
categoria(modelo)
# Out:
# A espécie é invasora, perigo de desequilíbrio da fauna do ecossistema!! (classe: invasor-alga-assassina)

# %%
display(Image(filename="/content/alga-processed.jpg"))

# %% [markdown]
# ## **Lixo**

# %% [markdown]
# ### **Bitucas de Cigarro**

# %%
# Imagem para teste do modelo:
modelo = model.predict("/content/cigarro.jpg", confidence=40, overlap=30).json()
print(modelo)
# Out:
# {'predictions': [{'x': 252, 'y': 376, 'width': 90, 'height': 99, 'confidence': 0.9875631928443909, 'class': 'lixo-bituca-cigarro', 'class_id': 5, 'detection_id': 'a442919d-d061-4042-927e-ba28801a8b90', 'image_path': '/content/cigarro.jpg', 'prediction_type': 'ObjectDetectionModel'}, {'x': 183, 'y': 350, 'width': 70, 'height': 99, 'confidence': 0.9789035320281982, 'class': 'lixo-bituca-cigarro', 'class_id': 5, 'detection_id': 'c1d72807-d170-4179-a22c-40f94313366d', 'image_path': '/content/cigarro.jpg', 'prediction_type': 'ObjectDetectionModel'}, {'x': 88, 'y': 335, 'width': 122, 'height': 86, 'confidence': 0.9707098007202148, 'class': 'lixo-bituca-cigarro', 'class_id': 5, 'detection_id': 'be904e6b-a9bd-4147-93af-e860f36e1f7e', 'image_path': '/content/cigarro.jpg', 'prediction_type': 'ObjectDetectionModel'}, {'x': 612, 'y': 353, 'width': 169, 'height': 85, 'confidence': 0.9655485153198242, 'class': 'lixo-bituca-cigarro', 'class_id': 5, 'detection_id': '5cb53a7d-af60-44f2-8c0d-b99099c01
# ...

# %%
# Imagem para teste do modelo:
model.predict("/content/cigarro.jpg", confidence=40, overlap=30).save("/content/cigarro-processed.jpg")

# %%
categoria(modelo)
# Out:
# Lixo encontrado no mar!! (classe: lixo-bituca-cigarro)

# %%
display(Image(filename="/content/cigarro-processed.jpg"))

# %% [markdown]
# ### **Garrafas Pet**

# %%
# Imagem para teste do modelo:
modelo = model.predict("/content/garrafa.jpg", confidence=40, overlap=30).json()
print(modelo)
# Out:
# {'predictions': [{'x': 433, 'y': 139, 'width': 55, 'height': 57, 'confidence': 0.9726482033729553, 'class': 'lixo-garrafa-pet', 'class_id': 6, 'detection_id': '04eb4dcf-58f3-4bba-9ee4-b01b2975fa8c', 'image_path': '/content/garrafa.jpg', 'prediction_type': 'ObjectDetectionModel'}, {'x': 196, 'y': 447, 'width': 87, 'height': 83, 'confidence': 0.9592074155807495, 'class': 'lixo-garrafa-pet', 'class_id': 6, 'detection_id': 'a24cd500-ecb6-40b7-810d-af2b5674c7f3', 'image_path': '/content/garrafa.jpg', 'prediction_type': 'ObjectDetectionModel'}, {'x': 65, 'y': 332, 'width': 56, 'height': 30, 'confidence': 0.9535452723503113, 'class': 'lixo-garrafa-pet', 'class_id': 6, 'detection_id': 'c603565f-3551-427c-81f4-e74fa0736175', 'image_path': '/content/garrafa.jpg', 'prediction_type': 'ObjectDetectionModel'}, {'x': 312, 'y': 321, 'width': 52, 'height': 31, 'confidence': 0.9357300400733948, 'class': 'lixo-garrafa-pet', 'class_id': 6, 'detection_id': '54fe332c-556b-46c7-8c47-aaad3f62837c', 'image_p
# ...

# %%
# Imagem para teste do modelo:
model.predict("/content/garrafa.jpg", confidence=40, overlap=30).save("/content/garrafa-processed.jpg")

# %%
categoria(modelo)
# Out:
# Lixo encontrado no mar!! (classe: lixo-garrafa-pet)

# %%
display(Image(filename="/content/garrafa-processed.jpg"))

# %% [markdown]
# ### **Sacolas Plásticas**

# %%
# Imagem para teste do modelo:
modelo = model.predict("/content/sacola.jpeg", confidence=40, overlap=30).json()
print(modelo)
# Out:
# {'predictions': [{'x': 139.0, 'y': 80.5, 'width': 140.0, 'height': 97.0, 'confidence': 0.8807013630867004, 'class': 'lixo-sacola-plastica', 'class_id': 7, 'detection_id': 'bc75cff5-e971-40e5-9ad4-c08a419217a5', 'image_path': '/content/sacola.jpeg', 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': '275', 'height': '183'}}

# %%
# Imagem para teste do modelo:
model.predict("/content/sacola.jpeg", confidence=40, overlap=30).save("/content/sacola-processed.jpg")

# %%
categoria(modelo)
# Out:
# Lixo encontrado no mar!! (classe: lixo-sacola-plastica)

# %%
display(Image(filename="/content/sacola-processed.jpg"))
