# %%
import pandas as pd

# %%
df = pd.read_csv('/content/global-plastics-production.csv')

df
# Out:
#    Entity      Code  Year  Annual plastic production between 1950 and 2019
# 0   World  OWID_WRL  1950                                          2000000
# 1   World  OWID_WRL  1951                                          2000000
# 2   World  OWID_WRL  1952                                          2000000
# 3   World  OWID_WRL  1953                                          3000000
# 4   World  OWID_WRL  1954                                          3000000
# ..    ...       ...   ...                                              ...
# 64  World  OWID_WRL  2015                                        381000000
# 65  World  OWID_WRL  2016                                        400050000
# 66  World  OWID_WRL  2017                                        420052500
# 67  World  OWID_WRL  2018                                        441055140
# 68  World  OWID_WRL  2019                                        459746020
#
# [69 rows x 4 columns]

# %%
df = df[(df['Year'] >= 2000) & (df['Year'] <= 2019)]

df
# Out:
#    Entity      Code  Year  Annual plastic production between 1950 and 2019
# 49  World  OWID_WRL  2000                                        213000000
# 50  World  OWID_WRL  2001                                        218000000
# 51  World  OWID_WRL  2002                                        231000000
# 52  World  OWID_WRL  2003                                        241000000
# 53  World  OWID_WRL  2004                                        256000000
# 54  World  OWID_WRL  2005                                        263000000
# 55  World  OWID_WRL  2006                                        280000000
# 56  World  OWID_WRL  2007                                        295000000
# 57  World  OWID_WRL  2008                                        281000000
# 58  World  OWID_WRL  2009                                        288000000
# 59  World  OWID_WRL  2010                                        313000000
# ...

# %%
df2 = pd.read_csv('/content/plastic-fate.csv')

df2 = df2[df2['Entity'].str.contains("World")]

df2
# Out:
#     Entity      Code  Year    Recycled  Incinerated  Littered and mismanaged  \
# 180  World  OWID_WRL  2000   5783667.0   16980004.0                 40635292
# 181  World  OWID_WRL  2001   6529903.0   18570814.0                 42657704
# 182  World  OWID_WRL  2002   7439750.0   20530800.0                 45354524
# 183  World  OWID_WRL  2003   8383408.0   22507442.0                 47831170
# 184  World  OWID_WRL  2004   9459860.0   24743732.0                 50646040
# 185  World  OWID_WRL  2005  10492602.0   26828640.0                 52868510
# 186  World  OWID_WRL  2006  11721061.0   29326584.0                 55713400
# 187  World  OWID_WRL  2007  13053889.0   32007148.0                 58640348
# 188  World  OWID_WRL  2008  13923892.0   33589484.0                 59203064
# 189  World  OWID_WRL  2009  15146142.0   35934470.0                 61048170
# 190  World  OWID_WRL  2010  16869304.0   39280410.0                 64469760
# ...

# %%
df3 = pd.read_csv('/content/plastic-waste-accumulated-in-oceans.csv')

df3 = df3[df3['Entity'].str.contains("World")]
682.204
df3
# Out:
#     Entity      Code  Year  \
# 180  World  OWID_WRL  2000
# 181  World  OWID_WRL  2001
# 182  World  OWID_WRL  2002
# 183  World  OWID_WRL  2003
# 184  World  OWID_WRL  2004
# 185  World  OWID_WRL  2005
# 186  World  OWID_WRL  2006
# 187  World  OWID_WRL  2007
# 188  World  OWID_WRL  2008
# 189  World  OWID_WRL  2009
# 190  World  OWID_WRL  2010
# 191  World  OWID_WRL  2011
# 192  World  OWID_WRL  2012
# 193  World  OWID_WRL  2013
# 194  World  OWID_WRL  2014
# 195  World  OWID_WRL  2015
# 196  World  OWID_WRL  2016
# 197  World  OWID_WRL  2017
# 198  World  OWID_WRL  2018
# 199  World  OWID_WRL  2019
#
#      Plastic leakage to aquatic envrionment - Leakage type: Accumulated stock in oceans
# 180                                          8471748.0
# 181                                          9153952.0
# 182                                          9881777.0
# 183                                         10656836.0
# 184                                         11481840.0
# ...

# %%
df.loc

# %%
df['Annual plastic production between 1950 and 2019']
# Out:
# 49    213000000
# 50    218000000
# 51    231000000
# 52    241000000
# 53    256000000
# 54    263000000
# 55    280000000
# 56    295000000
# 57    281000000
# 58    288000000
# 59    313000000
# 60    325000000
# 61    338000000
# 62    352000000
# 63    367000000
# 64    381000000
# 65    400050000
# 66    420052500
# 67    441055140
# 68    459746020
# Name: Annual plastic production between 1950 and 2019, dtype: int64

# %%
df.reset_index(drop=True, inplace=True)
df2.reset_index(drop=True, inplace=True)

# %%
df2
# Out:
#    Entity      Code  Year    Recycled  Incinerated  Littered and mismanaged  \
# 0   World  OWID_WRL  2000   5783667.0   16980004.0                 40635292
# 1   World  OWID_WRL  2001   6529903.0   18570814.0                 42657704
# 2   World  OWID_WRL  2002   7439750.0   20530800.0                 45354524
# 3   World  OWID_WRL  2003   8383408.0   22507442.0                 47831170
# 4   World  OWID_WRL  2004   9459860.0   24743732.0                 50646040
# 5   World  OWID_WRL  2005  10492602.0   26828640.0                 52868510
# 6   World  OWID_WRL  2006  11721061.0   29326584.0                 55713400
# 7   World  OWID_WRL  2007  13053889.0   32007148.0                 58640348
# 8   World  OWID_WRL  2008  13923892.0   33589484.0                 59203064
# 9   World  OWID_WRL  2009  15146142.0   35934470.0                 61048170
# 10  World  OWID_WRL  2010  16869304.0   39280410.0                 64469760
# ...

# %%
df
# Out:
#    Entity      Code  Year  Annual plastic production between 1950 and 2019
# 0   World  OWID_WRL  2000                                        213000000
# 1   World  OWID_WRL  2001                                        218000000
# 2   World  OWID_WRL  2002                                        231000000
# 3   World  OWID_WRL  2003                                        241000000
# 4   World  OWID_WRL  2004                                        256000000
# 5   World  OWID_WRL  2005                                        263000000
# 6   World  OWID_WRL  2006                                        280000000
# 7   World  OWID_WRL  2007                                        295000000
# 8   World  OWID_WRL  2008                                        281000000
# 9   World  OWID_WRL  2009                                        288000000
# 10  World  OWID_WRL  2010                                        313000000
# ...

# %%
colunas_para_trazer = ['Annual plastic production between 1950 and 2019']
colunas = df[colunas_para_trazer]

# Concatenar as colunas de df1 ao df2
df_final = pd.concat([df2, colunas], axis=1)

# %%
df_final
# Out:
#    Entity      Code  Year    Recycled  Incinerated  Littered and mismanaged  \
# 0   World  OWID_WRL  2000   5783667.0   16980004.0                 40635292
# 1   World  OWID_WRL  2001   6529903.0   18570814.0                 42657704
# 2   World  OWID_WRL  2002   7439750.0   20530800.0                 45354524
# 3   World  OWID_WRL  2003   8383408.0   22507442.0                 47831170
# 4   World  OWID_WRL  2004   9459860.0   24743732.0                 50646040
# 5   World  OWID_WRL  2005  10492602.0   26828640.0                 52868510
# 6   World  OWID_WRL  2006  11721061.0   29326584.0                 55713400
# 7   World  OWID_WRL  2007  13053889.0   32007148.0                 58640348
# 8   World  OWID_WRL  2008  13923892.0   33589484.0                 59203064
# 9   World  OWID_WRL  2009  15146142.0   35934470.0                 61048170
# 10  World  OWID_WRL  2010  16869304.0   39280410.0                 64469760
# ...

# %%
df3.reset_index(drop=True, inplace=True)

# %%
colunas_para_trazer = ['Plastic leakage to aquatic envrionment - Leakage type: Accumulated stock in oceans']
colunas = df3[colunas_para_trazer]

# Concatenar as colunas de df1 ao df2
df_final = pd.concat([df_final, colunas], axis=1)

# %%
df_final
# Out:
#    Entity      Code  Year    Recycled  Incinerated  Littered and mismanaged  \
# 0   World  OWID_WRL  2000   5783667.0   16980004.0                 40635292
# 1   World  OWID_WRL  2001   6529903.0   18570814.0                 42657704
# 2   World  OWID_WRL  2002   7439750.0   20530800.0                 45354524
# 3   World  OWID_WRL  2003   8383408.0   22507442.0                 47831170
# 4   World  OWID_WRL  2004   9459860.0   24743732.0                 50646040
# 5   World  OWID_WRL  2005  10492602.0   26828640.0                 52868510
# 6   World  OWID_WRL  2006  11721061.0   29326584.0                 55713400
# 7   World  OWID_WRL  2007  13053889.0   32007148.0                 58640348
# 8   World  OWID_WRL  2008  13923892.0   33589484.0                 59203064
# 9   World  OWID_WRL  2009  15146142.0   35934470.0                 61048170
# 10  World  OWID_WRL  2010  16869304.0   39280410.0                 64469760
# ...

# %%
df_final.to_csv('/content/df_final.csv', index=False)
